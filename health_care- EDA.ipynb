# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 # !pip install matplotlib --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
#importing dependencies
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from collections import defaultdict

# %%
df= pd.read_csv('/content/drive/MyDrive/capstone project data/Health_care.csv')

# %%
def overview(df):
    print('\033[1;36mINITIAL DATASET OVERVIEW\033[0m')
    print('\033[1;3m1. Number of records:\033[0m',df.shape[0])
    print(' — — — — -')
    print('\033[1;3m2. Number of features:\033[0m', df.shape[1])
    print(' — — — — -')
    print('\033[1;3m3. Basic overview:\033[0m')
    print(df.info())
    print(' — — — — -')
    print('\033[1;3m4. Statistical summary:\033[0m\n',df.describe())
    print(' — — — — -')
    print('\033[1;3m5. Data types:\033[0m\n', df.dtypes)
    print(' — — — — -')
    print('\033[1;3m6. First 5 records:\033[0m\n',df.head())
    print(' — — — — -')
    print('\033[1;3m7. Last 5 records:\033[0m\n', df.tail())

# %%
overview(df)
# Out:
# INITIAL DATASET OVERVIEW
# 1. Number of records: 567670
#  — — — — -
# 2. Number of features: 25
#  — — — — -
# 3. Basic overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567670 entries, 0 to 567669
# Data columns (total 25 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Product_id      567670 non-null  object
#  1   description     487540 non-null  object
#  2   title           567670 non-null  object
#  3   imUrl           567670 non-null  object
#  4   related         567670 non-null  object
#  5   salesRank       567670 non-null  int64
#  6   categories      567670 non-null  object
#  7   price           567670 non-null  float64
#  8   brand           567666 non-null  object
#  9   reviewerID      567670 non-null  object
#  10  reviewerName    567632 non-null  object
#  11  reviewText      567593 non-null  object
#  12  overall         567670 non-null  float64
#  13  summary         567660 non-null  object
#  14  unixReviewTime  567670 non-null  int64
#  15  reviewTime      567670 non-null  object
#  16  sentiment       567670 non-null  object
#  17  Helpful         567670 non-null  int64
#  18  Not_helpful     567670 non-null  int64
#  19  helpful_rate    567670 non-null  float64
#  20  neg             567670 non-null  float64
#  21  neu             567670 non-null  float64
#  22  pos             567670 non-null  float64
#  23  polarity        567670 non-null  float64
#  24  word_count      567670 non-null  int64
# dtypes: float64(7), int64(5), object(13)
# memory usage: 108.3+ MB
# None
#  — — — — -
# 4. Statistical summary:
#            salesRank          price        overall  unixReviewTime  \
# count  5.676700e+05  567670.000000  567670.000000    5.676700e+05
# mean   4.312266e+04      27.696443       4.127239    1.360862e+09
# std    8.731559e+04      36.752535       1.320473    4.454637e+07
# min    2.000000e+00       0.010000       1.000000    9.568800e+08
# 25%    2.389000e+03       9.800000       4.000000    1.351210e+09
# 50%    1.094800e+04      17.680000       5.000000    1.373069e+09
# 75%    4.262600e+04      31.990000       5.000000    1.390954e+09
# max    3.294288e+06     999.000000       5.000000    1.406074e+09
#
#              Helpful    Not_helpful   helpful_rate            neg  \
# count  567670.000000  567670.000000  567670.000000  567670.000000
# mean        2.033046       0.591953       0.330456       0.052910
# std        21.207904       2.670069       0.434627       0.063366
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.037000
# 75%         1.000000       0.000000       0.860000       0.084000
# max      9166.000000     756.000000       1.000000       1.000000
#
#                  neu            pos       polarity     word_count
# count  567670.000000  567670.000000  567670.000000  567670.000000
# mean        0.770153       0.176814       0.492601      67.099137
# std         0.115551       0.119453       0.520227      79.708007
# min         0.000000       0.000000      -0.999500       0.000000
# 25%         0.706000       0.095000       0.238200      26.000000
# 50%         0.782000       0.159000       0.709600      42.000000
# 75%         0.848000       0.242000       0.888500      78.000000
# max         1.000000       1.000000       1.000000    5989.000000
#  — — — — -
# 5. Data types:
#  Product_id         object
# description        object
# title              object
# imUrl              object
# related            object
# salesRank           int64
# categories         object
# price             float64
# brand              object
# reviewerID         object
# reviewerName       object
# reviewText         object
# overall           float64
# summary            object
# unixReviewTime      int64
# reviewTime         object
# sentiment          object
# Helpful             int64
# Not_helpful         int64
# helpful_rate      float64
# neg               float64
# neu               float64
# pos               float64
# polarity          float64
# word_count          int64
# dtype: object
#  — — — — -
# 6. First 5 records:
#     Product_id                                        description  \
# 0  B0059IU3TG  Absonutrix Fucoxanthin Topical Thermogenic Sli...
# 1  B001AJ6YS2  The fully washable Philips Norelco 7310XL Men'...
# 2  B00AYV59WY                                                NaN
# 3  B00H7SDL4A  Wahl 8483 pilot hair clipper. Smaller is bette...
# 4  B000XPGPXS  Native to southern India, the use of Neem Oil ...
#
#                                                title  \
# 0  Absonutrix Fucoxanthin Slim Patches - 30 Patch...
# 1          Philips Norelco 7310 Men's Shaving System
# 2  Scott Extra Soft Bath Tissue Mega Roll, 12 Cou...
# 3  Wahl 8483 Pilot Professional Corded Hair Clipp...
# 4                 NOW Foods Neem Oil, 1-Fluid Ounce.
#
#                                                imUrl  \
# 0  http://ecx.images-amazon.com/images/I/614vz80j...
# 1  http://ecx.images-amazon.com/images/I/31kbFfBR...
# 2  http://ecx.images-amazon.com/images/I/51OI%2BI...
# 3  http://ecx.images-amazon.com/images/I/51Xcw0V3...
# 4  http://ecx.images-amazon.com/images/I/31kCkyT4...
#
#                                              related  salesRank  \
# 0  {'also_bought': ['B0059IAWNI', 'B005FYO4OE', '...      36711
# 1  {'also_bought': ['B000068PBT', 'B001AJ8YGC', '...      15682
# 2  {'also_bought': ['B00HFQ2T06', 'B00BGN8PLG', '...       1517
# 3  {'also_bought': ['B000H7O5M0', 'B00FKR7SZS', '...     129649
# 4  {'also_bought': ['B000293X4E', 'B00CAQ7C8K', '...       8850
#
#                                           categories  price  \
# 0  [['Health & Personal Care', 'Vitamins & Dietar...  15.95
# 1  [['Health & Personal Care', 'Personal Care', '...  79.99
# 2  [['Health & Personal Care', 'Household Supplie...  23.99
# 3  [['Health & Personal Care', 'Personal Care', '...  44.20
# 4  [['Health & Personal Care', 'Vitamins & Dietar...   4.89
#
#                           brand      reviewerID  ...  reviewTime sentiment  \
# 0  Absonutrix Fucoxanthin Patch  A1L7MPGNGTCDOG  ...  2014-02-12  Negative
# 1                       Philips   AM12RRYC66CO1  ...  2012-03-11  Negative
# 2                         SCOTT  A3CTL2OU26LA5A  ...  2013-12-11  Negative
# 3                          WAHL  A2A4T6F9AXQQP3  ...  2014-04-05  Negative
# 4                     Now Foods  A17OABMG1I5TAG  ...  2014-02-23  Negative
#
#    Helpful Not_helpful  helpful_rate    neg    neu    pos  polarity  \
# 0        0           0          0.00  0.000  1.000  0.000    0.0000
# 1        0           2          0.00  0.139  0.839  0.022   -0.7896
# 2        0           1          0.00  0.128  0.872  0.000   -0.6635
# 3        2           1          0.67  0.417  0.533  0.051   -0.9293
# 4        0           2          0.00  0.045  0.827  0.127    0.5674
#
#    word_count
# 0          20
# 1          50
# 2          54
# 3          26
# 4          30
#
# [5 rows x 25 columns]
#  — — — — -
# 7. Last 5 records:
#          Product_id                                        description  \
# 567665  B002RBF1PO  This fabulous traditional double edge safety r...
# 567666  B001AJ6YS2  The fully washable Philips Norelco 7310XL Men'...
# 567667  B0002DSVTC  The Energizer 2016 Lithium battery is for use ...
# 567668  B000WHNI2I                                                NaN
# 567669  B00068OTBW  When it comes to groundbreaking advances in te...
#
#                                                     title  \
# 567665  Edwin Jagger DE89Lbl Lined Detail Chrome Plate...
# 567666          Philips Norelco 7310 Men's Shaving System
# 567667  Energizer 2016 3V Lithium Button Cell Battery ...
# 567668  Philips Sonicare HX6013 ProResults Brush Head ...
# 567669                 Maximum Living: Mineralrich, 32 oz
#
#                                                     imUrl  \
# 567665  http://ecx.images-amazon.com/images/I/31ELIZ4G...
# 567666  http://ecx.images-amazon.com/images/I/31kbFfBR...
# 567667  http://ecx.images-amazon.com/images/I/51wXJkFS...
# 567668  http://ecx.images-amazon.com/images/I/31kpCZM4...
# 567669  http://ecx.images-amazon.com/images/I/41bKs9ZU...
#
#                                                   related  salesRank  \
# 567665  {'also_bought': ['B004SGKMA0', 'B003WR3QSG', '...        689
# 567666  {'also_bought': ['B000068PBT', 'B001AJ8YGC', '...      15682
# 567667  {'also_bought': ['B0044C68G0', 'B001F0RCMI', '...        572
# 567668  {'also_bought': ['B00CUG26Z4', 'B0086VI9TO', '...        371
# 567669  {'also_bought': ['B00068OTE4', 'B00028O41Q', '...       1711
#
#                                                categories  price  \
# 567665  [['Health & Personal Care', 'Personal Care', '...  32.49
# 567666  [['Health & Personal Care', 'Personal Care', '...  79.99
# 567667  [['Health & Personal Care', 'Household Supplie...   2.68
# 567668  [['Health & Personal Care', 'Personal Care', '...  23.95
# 567669  [['Health & Personal Care', 'Vitamins & Dietar...  19.99
#
#                  brand      reviewerID  ...  reviewTime sentiment  Helpful  \
# 567665    Edwin Jagger   AGAGC3FAW87RR  ...  2014-03-12  Positive        0
# 567666         Philips   A2YZESVHVKDC7  ...  2011-06-28  Positive        0
# 567667       Energizer   AGYYWW2R9XH5G  ...  2012-12-08  Positive        2
# 567668         Philips  A2ZM5F1K76ZFUV  ...  2012-01-05  Positive        0
# 567669  Maximum Living   ALX52O4TI80V8  ...  2013-06-07  Positive        3
#
#        Not_helpful  helpful_rate    neg    neu    pos  polarity  word_count
# 567665           0          0.00  0.000  0.765  0.235    0.9192          57
# 567666           0          0.00  0.000  0.896  0.104    0.7906          73
# 567667           1          0.67  0.044  0.823  0.132    0.6186          42
# 567668           0          0.00  0.000  0.757  0.243    0.8898          45
# 567669           1          0.75  0.010  0.748  0.242    0.9816         116
#
# [5 rows x 25 columns]

# %%
cat=df.select_dtypes(include="object")                
num=df.select_dtypes(exclude="object") 
a=list(cat.columns)                                    # Creating List of the categorical columns
b=list(num.columns)                                    #creating list of the numerical columns

# %%
from tabulate import tabulate
print(tabulate({"categorical":a,"numerical":b},headers=["Categorical","Numerical"]))
# Out:
# Categorical    Numerical
# -------------  --------------
# Product_id     salesRank
# description    price
# title          overall
# imUrl          unixReviewTime
# related        Helpful
# categories     Not_helpful
# brand          helpful_rate
# reviewerID     neg
# reviewerName   neu
# reviewText     pos
# summary        polarity
# reviewTime     word_count
# sentiment

# %%
df.isnull().sum()    #checking null values in dataset
# Out:
# Product_id            0
# description       80130
# title                 0
# imUrl                 0
# related               0
# salesRank             0
# categories            0
# price                 0
# brand                 4
# reviewerID            0
# reviewerName         38
# reviewText           77
# overall               0
# summary              10
# unixReviewTime        0
# reviewTime            0
# sentiment             0
# Helpful               0
# Not_helpful           0
# helpful_rate          0
# neg                   0
# neu                   0
# pos                   0
# polarity              0
# word_count            0
# dtype: int64

# %% [markdown]
# <font color='sienna'> As we converted the data to csv some empty strings were converted to null values as the number of null values is very less we will drop the values.

# %%
df.drop('description',axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()    #checking null values in dataset
# Out:
# Product_id        0
# title             0
# imUrl             0
# related           0
# salesRank         0
# categories        0
# price             0
# brand             0
# reviewerID        0
# reviewerName      0
# reviewText        0
# overall           0
# summary           0
# unixReviewTime    0
# reviewTime        0
# sentiment         0
# Helpful           0
# Not_helpful       0
# helpful_rate      0
# neg               0
# neu               0
# pos               0
# polarity          0
# word_count        0
# dtype: int64

# %% [markdown]
# ## Sweet Report

# %%
# !pip install sweetviz
#importing sweetviz and visualizing our data
import sweetviz as sv
sweet_report = sv.analyze(df)
sweet_report.show_html('/content/drive/MyDrive/capstone project data/healthcare_sweetviz_report.html')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sweetviz
#   Downloading sweetviz-2.1.4-py3-none-any.whl (15.1 MB)
#      |████████████████████████████████| 15.1 MB 4.6 MB/s
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.8/dist-packages (from sweetviz) (4.64.1)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.8/dist-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /usr/local/lib/python3.8/dist-packages (from sweetviz) (1.3.5)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from sweetviz) (1.21.6)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from sweetviz) (1.7.3)
# Requirement already satisfied: importlib-resources>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from sweetviz) (5.10.0)
# Requirement already satisfied: matplotlib>=3.1.3 in /usr/local/lib/python3.8/dist-packages (from sweetviz) (3.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.2.0->sweetviz) (3.11.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.3->sweetviz) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.3->sweetviz) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.3->sweetviz) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.0.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.15.0)
# Installing collected packages: sweetviz
# Successfully installed sweetviz-2.1.4
#                                              |          | [  0%]   00:00 -> (? left)
# Report /content/drive/MyDrive/capstone project data/healthcare_sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Exploratory Data Analysis

# %%
import nltk #for text analysis
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words=stopwords.words('english')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['review_without_stopwords'] = df['reviewText'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
df.head(2)
# Out:
#    Product_id                                              title  \
# 0  B0059IU3TG  Absonutrix Fucoxanthin Slim Patches - 30 Patch...
# 1  B001AJ6YS2          Philips Norelco 7310 Men's Shaving System
#
#                                                imUrl  \
# 0  http://ecx.images-amazon.com/images/I/614vz80j...
# 1  http://ecx.images-amazon.com/images/I/31kbFfBR...
#
#                                              related  salesRank  \
# 0  {'also_bought': ['B0059IAWNI', 'B005FYO4OE', '...      36711
# 1  {'also_bought': ['B000068PBT', 'B001AJ8YGC', '...      15682
#
#                                           categories  price  \
# 0  [['Health & Personal Care', 'Vitamins & Dietar...  15.95
# 1  [['Health & Personal Care', 'Personal Care', '...  79.99
#
#                           brand      reviewerID               reviewerName  \
# 0  Absonutrix Fucoxanthin Patch  A1L7MPGNGTCDOG                   djpetrik
# 1                       Philips   AM12RRYC66CO1  Tati Ard "collegebuyer09"
#
#    ... sentiment  Helpful Not_helpful  helpful_rate    neg    neu    pos  \
# 0  ...  Negative        0           0           0.0  0.000  1.000  0.000
# 1  ...  Negative        0           2           0.0  0.139  0.839  0.022
#
#    polarity  word_count                           review_without_stopwords
# 0    0.0000          20  dont order anything helpfulthat listed descrip...
# 1   -0.7896          50  never-ever buy product philips company paid re...
#
# [2 rows x 25 columns]

# %%
#Filtering data
df_pos = df[df['sentiment']=='Positive']
df_neg = df[df['sentiment']=='Negative']
df_neu = df[df['sentiment']=='Neutral']

# %%
pos_words = pd.Series(' '.join(df_pos['review_without_stopwords']).lower().split()).value_counts()[:20]
neg_words = pd.Series(' '.join(df_neg['review_without_stopwords']).lower().split()).value_counts()[:20]
neu_words = pd.Series(' '.join(df_neu['review_without_stopwords']).lower().split()).value_counts()[:20]

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.figure(figsize=(25,15))
           
plt.subplot(311)
plt.title('Positive Words',fontsize=23)
sb.barplot(x=pos_words.index ,y = pos_words.values )
plt.xticks(fontsize=20)

plt.subplot(312)
plt.title('Negative Words',fontsize=23)
sb.barplot(x=neg_words.index ,y = neg_words.values )
plt.xticks(fontsize=20)

plt.subplot(313)
plt.title('Neutral Words',fontsize=23)
sb.barplot(x= neu_words.index , y = neu_words.values )
plt.xticks(fontsize=20)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## <font color='dimgray'>Wordcloud-positive reviews

# %%
text = df_pos["reviewText"]
wordcloud = WordCloud(
    width = 3000,
    height = 1000,
    background_color = 'black',
    stopwords = stop_words).generate(str(text))
fig = plt.figure(
    figsize = (10, 5),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## <font color='dimgray'>Wordcloud-Neutral reviews

# %%
text = df_neu["reviewText"]
wordcloud = WordCloud(
    width = 3000,
    height = 1000,
    background_color = 'black',
    stopwords = stop_words).generate(str(text))
fig = plt.figure(
    figsize = (10,5),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## <font color='dimgray'>Wordcloud-Negative reviews

# %%
text = df_neg["reviewText"]
wordcloud = WordCloud(
    width = 3000,
    height = 1000,
    background_color = 'black',
    stopwords = stop_words).generate(str(text))
fig = plt.figure(
    figsize = (10, 5),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
ratings = df["overall"].value_counts()
numbers = ratings.index
quantity = ratings.values

custom_colors = ["skyblue", "yellowgreen", 'tomato', "blue", "red"]
plt.figure(figsize=(10, 5))
plt.pie(quantity, labels=numbers, colors=custom_colors,autopct='%1.f%%')
central_circle = plt.Circle((0,0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of Amazon Product Ratings", fontsize=20)
plt.show()

# %% [markdown]
# Interpretation:
# <font color='sienna'> **The overall rating of the product rating that is highest is rating 5.**

# %%
plt.figure(figsize=(10,7))
ax=sns.countplot(df['sentiment'],palette='twilight')
plt.title('Distibutribution of customer sentiments',fontsize=20)
ax.bar_label(ax.containers[0],padding = 2,fontsize=10)
plt.show()

# %% [markdown]
# Interpretation:
# <font color='sienna'> **Most of the reviews have positive sentiment.**

# %%
plt.figure(figsize = (10,6))
ax=sns.countplot(df['overall'])
plt.title('Total Review count for each Rating', fontsize=20)
plt.xlabel('Rating Class')
plt.ylabel('Number of Reviews')
ax.bar_label(ax.containers[0],padding = 2,fontsize=10)
plt.show()

# %% [markdown]
# Interpretation:
# <font color='sienna'> **Most of the reviews have 5 star rating and the number of reviews where the count is less has got rating as 2.**

# %%
#grouping the brand as per price
brand_price=df.groupby(by="brand")["price"].mean()
top20_price_brand=brand_price.sort_values(ascending=False)[:20]
last20_price_brand=brand_price.sort_values(ascending=False)[-20:]

# %%
last20_price_brand=last20_price_brand.sort_values()

# %%
plt.figure(figsize = (20,5))
ax=sns.barplot(top20_price_brand.index,top20_price_brand.values,palette='twilight')
plt.title('Top 20 Expensive Brands', fontsize=20)
plt.xlabel('Brands')
plt.ylabel('Price')
plt.xticks(rotation=90,fontsize=10)
ax.bar_label(ax.containers[0],padding = 2,fontsize=10)
plt.show()

# %% [markdown]
# Interpretation:
# <font color='sienna'> **Shoprider is the most expensive brand in the health_care dataset.**

# %%
plt.figure(figsize = (20,5))
ax=sns.barplot(last20_price_brand.index,last20_price_brand.values,palette='twilight')
plt.title('Top 20 Inexpensive Brands',fontsize=20)
plt.xlabel('Brands')
plt.ylabel('Price')
plt.xticks(rotation=90,fontsize=10)
ax.bar_label(ax.containers[0],padding = 2,fontsize=10)
plt.show()

# %% [markdown]
# Interpretation:
# <font color='sienna'> **Millers Forge is the most inexpensive brand in the health_care dataset.**

# %%
#converting reviewTime to datetime datatype
df['reviewTime'] = pd.to_datetime(df['reviewTime'])

# %%
year_cat=df.groupby(by=df['reviewTime'].dt.year)["categories"].count()
plt.figure(figsize = (20,5))
ax=sns.barplot(year_cat.index,year_cat.values,palette="BuPu",errwidth=0)
plt.title('Total Review Numbers for Each Year',fontsize=20)
plt.xlabel('year')
plt.ylabel('Number of Reviews')
plt.xticks(fontsize=10)
ax.bar_label(ax.containers[0],padding = 2,fontsize=8,fontweight="bold")
plt.show()

# %% [markdown]
# Interpretation:
# <font color='sienna'> **Maximum review were recieved on the products in the year 2013.**

# %%
brands = df["brand"].value_counts()
plt.figure(figsize=(20,5))
brands[:20].plot(kind='bar',color='orange')
plt.title("Number of Reviews for Top 20 Brands",fontsize=20)
plt.xlabel('Brand Name')
plt.xticks(fontsize=10)
plt.ylabel('Number of Reviews')
plt.show()

# %% [markdown]
# Interpretation:
# <font color='sienna'> **Now foods Brand got the highest number of reviews.**

# %%
plt.figure(figsize = (15,6))
ax=df.groupby('overall')['helpful_rate'].mean().plot(kind='bar', color= 'midnightblue') 
plt.title("Helpfulness in rating",fontsize=20)
plt.xlabel("Rating",fontsize=15)
plt.ylabel("Helpfulness ratio",fontsize=15)
plt.xticks(rotation=0,fontsize=15)
ax.bar_label(ax.containers[0],padding = 2,fontsize=12)
plt.show()

# %% [markdown]
# Interpretation:
# <font color='sienna'> **Low rating and high rating review was most helpful for customers to buy the products.**

# %%
year_overall=df.groupby(by=df["reviewTime"].dt.year)["overall"].mean()
plt.figure(figsize = (20,5))
ax=sns.barplot(year_overall.index,year_overall.values,palette="twilight")
plt.title('Yearwise Average Rating',fontsize=20 )
plt.xlabel('year')
plt.ylabel('Average Ratings')
plt.xticks(fontsize=15)
ax.bar_label(ax.containers[0],padding = 2,fontsize=9)
plt.show()

# %%
## custom function for ngram generation ##
def generate_ngrams(text, n_gram=1):
    token = [token for token in text.lower().split(" ") if token != "" if token not in stop_words]
    ngrams = zip(*[token[i:] for i in range(n_gram)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
def horizontal_bar_chart(df, color):
    trace = go.Bar(
        y=df["word"].values[::-1],
        x=df["wordcount"].values[::-1],
        showlegend=False,
        orientation = 'h',
        marker=dict(
            color=color,
        ),
    )
    return trace

# %%
import plotly.graph_objs as go
from plotly.offline import iplot
from plotly import tools

# %%
## Get the bar chart from positive reviews ##
freq_dict = defaultdict(int)
for sent in df_pos["reviewText"]:
    for word in generate_ngrams(sent,2):
        freq_dict[word] += 1
fd_sorted = pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-1])
fd_sorted.columns = ["word", "wordcount"]
trace0 = horizontal_bar_chart(fd_sorted.head(25), 'green')

## Get the bar chart from neutral reviews ##
freq_dict = defaultdict(int)
for sent in df_neu["reviewText"]:
    for word in generate_ngrams(sent,2):
        freq_dict[word] += 1
fd_sorted = pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-1])
fd_sorted.columns = ["word", "wordcount"]
trace1 = horizontal_bar_chart(fd_sorted.head(25), 'grey')

## Get the bar chart from negative reviews ##
freq_dict = defaultdict(int)
for sent in df_neg["reviewText"]:
    for word in generate_ngrams(sent,2):
        freq_dict[word] += 1
fd_sorted = pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-1])
fd_sorted.columns = ["word", "wordcount"]
trace2 = horizontal_bar_chart(fd_sorted.head(25), 'brown')



# Creating two subplots
fig = tools.make_subplots(rows=3, cols=1, vertical_spacing=0.04,horizontal_spacing=0.25,
                          subplot_titles=["Bigram plots of Positive reviews", 
                                          "Bigram plots of Neutral reviews",
                                          "Bigram plots of Negative reviews"
                                          ])
fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 2, 1)
fig.append_trace(trace2, 3, 1)


fig['layout'].update(height=1000, width=800, paper_bgcolor='rgb(233,233,233)', title="Bigram Plots")
iplot(fig, filename='word-plots')
# Out:
# /usr/local/lib/python3.8/dist-packages/plotly/tools.py:461: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4691e7f9-c20c-435d-8dec-e25560977497" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4691e7f9-c20c-435d-8dec-e25560977497")) {                    Plotly.newPlot(                        "4691e7f9-c20c-435d-8dec-e25560977497",                        [{"marker":{"color":"green"},"orientation":"h","showlegend":false,"x":[4367,4404,4719,4719,4927,5066,5495,5751,5836,5845,5943,6020,6248,6509,6515,7173,8009,8811,9186,12212,12827,13276,13521,14580,15645],"xaxis":"x","y":["year old","good price","love product","feel like","product works","side effects","really like","make sure","using product","work well","years ago","recommend anyone","great price","first time","good product","every day","long time","recommend product","much better","works well","easy use","works great","would recommend","great product","highly recommend"],"yaxis":"y","type":"bar"},{"marker":{"color":"grey"},"orientation":"h","showlegend":false,"x":[421,428,429,434,439,455,456,461,462,498,500,505,524,533,536,537,589,656,663,691,782,809,871,953,1016],"xaxis":"x2","y":["little bit","really like","product works","would like","easy use","using product","every day","next time","would buy","long time","make sure","weight loss","last long","even though","works great","pretty good","feel like","first time","good product","fish oil","much better","thought would","would recommend","works well","work well"],"yaxis":"y2","type":"bar"},{"marker":{"color":"brown"},"orientation":"h","showlegend":false,"x":[740,745,755,775,794,797,814,829,871,875,898,900,906,908,1058,1129,1171,1180,1182,1395,1409,1416,1587,2566,5271],"xaxis":"x3","y":["could get","money back","would buy","something else","waste time","bought product","read reviews","would work","weight loss","feel like","using product","stopped working","buy product","every time","product work","even though","recommend product","customer service","work well","much better","save money","thought would","first time","would recommend","waste money"],"yaxis":"y3","type":"bar"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Bigram plots of Positive reviews","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Bigram plots of Neutral reviews","x":0.5,"xanchor":"center","xref":"paper","y":0.6533333333333333,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Bigram plots of Negative reviews","x":0.5,"xanchor":"center","xref":"paper","y":0.3066666666666667,"yanchor":"bottom","yref":"paper"}],"height":1000,"paper_bgcolor":"rgb(233,233,233)","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778 ...

# %%
## Get the bar chart from positive reviews ##
for sent in df_pos["reviewText"]:
    for word in generate_ngrams(sent,3):
        freq_dict[word] += 1
fd_sorted = pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-4])
fd_sorted.columns = ["word", "wordcount"]
trace0 = horizontal_bar_chart(fd_sorted.head(25), 'green')

## Get the bar chart from neutral reviews ##
freq_dict = defaultdict(int)
for sent in df_neu["reviewText"]:
    for word in generate_ngrams(sent,3):
        freq_dict[word] += 1
fd_sorted = pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-4])
fd_sorted.columns = ["word", "wordcount"]
trace1 = horizontal_bar_chart(fd_sorted.head(25), 'grey')

## Get the bar chart from negative reviews ##
freq_dict = defaultdict(int)
for sent in df_neg["reviewText"]:
    for word in generate_ngrams(sent,3):
        freq_dict[word] += 1
fd_sorted = pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-4])
fd_sorted.columns = ["word", "wordcount"]
trace2 = horizontal_bar_chart(fd_sorted.head(25), 'red')




# Creating two subplots
fig = tools.make_subplots(rows=3, cols=1, vertical_spacing=0.04, horizontal_spacing=0.05,
                          subplot_titles=["Tri-gram plots of Positive reviews", 
                                          "Tri-gram plots of Neutral reviews",
                                          "Tri-gram plots of Negative reviews"])
fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 2, 1)
fig.append_trace(trace2, 3, 1)
fig['layout'].update(height=1200, width=1200, paper_bgcolor='rgb(233,233,233)', title="Trigram Count Plots")
iplot(fig, filename='word-plots')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="972db002-fbda-4b6f-9adf-0b3c5098b3bf" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("972db002-fbda-4b6f-9adf-0b3c5098b3bf")) {                    Plotly.newPlot(                        "972db002-fbda-4b6f-9adf-0b3c5098b3bf",                        [{"marker":{"color":"green"},"orientation":"h","showlegend":false,"x":[350,357,364,378,392,403,417,458,477,486,498,505,514,567,585,608,702,789,832,886,1038,1100,1247,2263,3303],"xaxis":"x","y":["cod liver oil","couple years ago","year old daughter","negative side effects","stuff really works","first time tried","still going strong","thought would try","waste time money","easy use easy","never going fill","first aid kit","seems work well","really like product","used product years","works much better","product would recommend","great product great","get job done","coffee bean extract","highly recommend anyone","works really well","worth every penny","would definitely recommend","would recommend anyone"],"yaxis":"y","type":"bar"},{"marker":{"color":"grey"},"orientation":"h","showlegend":false,"x":[48,49,52,56,58,58,60,63,64,65,65,66,67,68,70,71,72,77,81,83,86,92,97,143,272],"xaxis":"x2","y":["would much better","formnot certified kosher","get close shave","buy another one","omega using amazon","mgstotal omega mgspercentage","mgsdha mgsepa dha","number manufactured u","pharmaceutical grade omega","minami nutrition platinum","plus d3 formula","would work better","price per mgs","gel cap followed","strength fish oil","price one mg","thought would try","omegavia pharma-grade fish","halal mg gel","oils super critical","certified kosher halal","product works well","omega per gel","get job done","per gel cap"],"yaxis":"y2","type":"bar"},{"marker":{"color":"red"},"orientation":"h","showlegend":false,"x":[61,62,63,65,66,68,71,76,78,80,81,85,88,88,93,103,105,109,117,126,134,152,205,317,568],"xaxis":"x3","y":["seemed like good","ended throwing away","product work well","like good idea","buy waste money","would give stars","work much better","thought would great","would work better","called customer service","thought would good","would never recommend","every time use","broke first time","wish could return","help lose weight","give one star","buy another one","health food store","try something else","work waste money","dont waste money","save money buy","complete waste money","would recommend product"],"yaxis":"y3","type":"bar"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Tri-gram plots of Positive reviews","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Tri-gram plots of Neutral reviews","x":0.5,"xanchor":"center","xref":"paper","y":0.6533333333333333,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Tri-gram plots of Negative reviews","x":0.5,"xanchor":"center","xref":"paper","y":0.3066666666666667,"yanchor":"bottom","yref":"paper"}],"height":1200,"paper_bgcolor":"rgb(233,233,233)","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0 ...

# %% [markdown]
# #<font color='dimgray'><center> End of file</center>
